# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# !pip install wandb
import wandb
from wandb.keras import WandbCallback
# Out:
# Requirement already satisfied: wandb in /usr/local/lib/python3.7/dist-packages (0.12.6)
# Requirement already satisfied: subprocess32>=3.5.3 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.5.4)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.1.24)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: configparser>=3.8.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.1.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: shortuuid>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.2)
# Requirement already satisfied: yaspin>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.1.0)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.7/dist-packages (from wandb) (0.1.2)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.4.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (3.7.4.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb) (5.0.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2021.5.30)
# Requirement already satisfied: termcolor<2.0.0,>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from yaspin>=1.0.0->wandb) (1.1.0)

# %%
# Installing pre-requisite for saving the model
# !pip install pyyaml h5py
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (3.1.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from h5py) (1.19.5)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py) (1.5.2)

# %%
# Mount google drive where dataset is stored at
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import necessary libraries
from tensorflow.keras.applications.resnet_v2 import ResNet50V2
from tensorflow.keras.applications.resnet_v2 import preprocess_input, decode_predictions
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D, BatchNormalization, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from IPython.display import Image, display
from random import randint

import os
import numpy as np
import pandas as pd

# %%
# Configuration settings 
configs = {
    'epochs': 20,
    'batch_size': 32, 
    'seed': 7,
    'learning_rate': 1e-3, #0.001
    'hidden_activation': 'relu',
    'output_activation': 'sigmoid',
    'optimizer': 'adam',
    'loss_function': 'binary_crossentropy',
    'metrics': ['accuracy'],
    'fc_layer_1_neurons' : 1024,
    'fc_layer_2_neurons' : 512,
    'fc_layer_3_neurons' : 256,
}

# Initialise Wandb
resnet_with_pretrained_celebA = wandb.init(
    name='resnet50V2_with_pretrained_celebA',
    project='CZ4042_Assignment_2_Resnet_Experiments',
    config= configs,
)

config = wandb.config
np.random.seed(config.seed)
tf.random.set_seed(config.seed)
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
#                     Syncing run <strong><a href="https://wandb.ai/dloe001/CZ4042_Assignment_2_Resnet_Experiments/runs/81i124vo" target="_blank">resnet50V2_with_pretrained_celebA</a></strong> to <a href="https://wandb.ai/dloe001/CZ4042_Assignment_2_Resnet_Experiments" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>

# %%
# Define the google drive path where data is stored
base_path = '/content/drive/MyDrive/CZ4042 Project Assignment 2/Models/'

# Load preprocessed dataset containing image path and gender as dataframe
df = pd.read_csv(base_path + 'processed_path_and_gender.txt', sep='\t')

# Split the dataset 80% train / 20% test
train_df, test_df = train_test_split(df, test_size=0.2, random_state = config.seed)

# Append the google drive path infront of the image path 
train_df['data_path'] = base_path + train_df['data_path'].astype(str)
test_df['data_path'] = base_path + test_df['data_path'].astype(str)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
# 5 random sample images from train_df
for i in range(5):
  randnum = randint(0, train_df.shape[0])
  print(train_df['data_path'].iloc[[randnum]])
  for imageName in train_df['data_path'].iloc[[randnum]]:
    display(Image(filename=imageName, width = 100, height = 100))
# Out:
# 3454    /content/drive/MyDrive/CZ4042 Project Assignme...
# Name: datadir, dtype: object
# 366    /content/drive/MyDrive/CZ4042 Project Assignme...
# Name: datadir, dtype: object
# 11944    /content/drive/MyDrive/CZ4042 Project Assignme...
# Name: datadir, dtype: object
# 3212    /content/drive/MyDrive/CZ4042 Project Assignme...
# Name: datadir, dtype: object
# 9110    /content/drive/MyDrive/CZ4042 Project Assignme...
# Name: datadir, dtype: object

# %%
# 5 random sample images from test_df
for i in range(5):
  randnum = randint(0, test_df.shape[0])
  print(test_df['data_path'].iloc[[randnum]])
  for imageName in test_df['data_path'].iloc[[randnum]]:
    display(Image(filename=imageName, width = 100, height = 100))
# Out:
# 9861    /content/drive/MyDrive/CZ4042 Project Assignme...
# Name: datadir, dtype: object
# 6000    /content/drive/MyDrive/CZ4042 Project Assignme...
# Name: datadir, dtype: object
# 1470    /content/drive/MyDrive/CZ4042 Project Assignme...
# Name: datadir, dtype: object
# 2288    /content/drive/MyDrive/CZ4042 Project Assignme...
# Name: datadir, dtype: object
# 9872    /content/drive/MyDrive/CZ4042 Project Assignme...
# Name: datadir, dtype: object

# %%
# Initialise ImageDataGenerator 
# Perform rescaling using resnet50V2's preprocess_input method
train_image_generated = ImageDataGenerator(preprocessing_function = preprocess_input)
test_image_generated = ImageDataGenerator(preprocessing_function = preprocess_input)

# Generate the rescaled train images from the dataframe given 
train_ds = train_image_generated.flow_from_dataframe(
    dataframe = train_df,
    x_col ='data_path',
    y_col = 'gender',
    batch_size = config.batch_size,
    seed = config.seed,
    shuffle = True,
    class_mode ='raw',
    target_size = (224,224),
)

# Generate the rescaled test images from the dataframe given 
test_ds = test_image_generated.flow_from_dataframe(
    dataframe = test_df,
    x_col = 'data_path',
    y_col = 'gender',
    batch_size = config.batch_size,
    seed = config.seed,
    shuffle = True,
    class_mode = 'raw',
    target_size = (224,224),
)
# Out:
# Found 9755 validated image filenames.
# Found 2439 validated image filenames.

# %%
# Creating the resnet50V2 model
def get_resnet50V2_model():

  seq = tf.keras.models.Sequential()

  seq.add(ResNet50V2(include_top=False, pooling = 'avg', weights ='imagenet', input_shape=(224,224,3)))

  seq.add(Flatten())

  seq.add(BatchNormalization())

  seq.add(Dense(config.fc_layer_1_neurons, activation = config.hidden_activation))

  seq.add(tf.keras.layers.Dropout(0.5))

  seq.add(BatchNormalization())

  seq.add(Dense(config.fc_layer_2_neurons, activation = config.hidden_activation))

  seq.add(tf.keras.layers.Dropout(0.5))

  seq.add(BatchNormalization())

  seq.add(Dense(config.fc_layer_3_neurons, activation = config.hidden_activation))

  seq.add(tf.keras.layers.Dropout(0.5))

  seq.add(BatchNormalization())

  seq.add(Dense(1, activation= config.output_activation))

  seq.layers[0].trainable = True

  return seq

# %%
model = get_resnet50V2_model()

# Load the pretrained celebA weights
model.load_weights('/content/drive/MyDrive/CZ4042 Project Assignment 2/Models/Resnet50V2 Experiments/model_celeba_tune_resNet50V2_v3.h5')

# Compile the model
model.compile(
    optimizer = config.optimizer,
    loss = config.loss_function,
    metrics = config.metrics,
)

# View summary of model
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94674944/94668760 [==============================] - 1s 0us/step
# 94683136/94668760 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23564800
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 2048)              8192
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 26,334,721
# Trainable params: 26,281,601
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
# Checkpoint storing path
checkpoint_path = base_path + "Model Checkpoints/" + "resnet50V2_with_pretrained_celebA_cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Model checkpoint to store best weights
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath= checkpoint_path,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# Training the model
train_history = model.fit(
    train_ds,
    epochs= config.epochs,
    use_multiprocessing=True,
    callbacks=[model_checkpoint_callback, WandbCallback()],
    validation_data=test_ds,
)
# Out:
# Epoch 1/20
# 305/305 [==============================] - 2904s 9s/step - loss: 0.5733 - accuracy: 0.7827 - val_loss: 0.3409 - val_accuracy: 0.8487
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/20
# 305/305 [==============================] - 168s 551ms/step - loss: 0.3294 - accuracy: 0.8575 - val_loss: 0.3069 - val_accuracy: 0.8713
# Epoch 3/20
# 305/305 [==============================] - 171s 560ms/step - loss: 0.2564 - accuracy: 0.8980 - val_loss: 0.2641 - val_accuracy: 0.8827
# Epoch 4/20
# 305/305 [==============================] - 171s 556ms/step - loss: 0.1885 - accuracy: 0.9304 - val_loss: 0.2517 - val_accuracy: 0.8950
# Epoch 5/20
# 305/305 [==============================] - 170s 557ms/step - loss: 0.1289 - accuracy: 0.9567 - val_loss: 0.2596 - val_accuracy: 0.9041
# Epoch 6/20
# 305/305 [==============================] - 170s 558ms/step - loss: 0.0875 - accuracy: 0.9713 - val_loss: 0.2772 - val_accuracy: 0.9053
# Epoch 7/20
# 305/305 [==============================] - 170s 556ms/step - loss: 0.0490 - accuracy: 0.9853 - val_loss: 0.3283 - val_accuracy: 0.9069
# Epoch 8/20
# 305/305 [==============================] - 169s 553ms/step - loss: 0.0348 - accuracy: 0.9888 - val_loss: 0.3514 - val_accuracy: 0.9082
# Epoch 9/20
# 305/305 [==============================] - 170s 556ms/step - loss: 0.0340 - accuracy: 0.9896 - val_loss: 0.3441 - val_accuracy: 0.9077
# Epoch 10/20
# 305/305 [==============================] - 171s 559ms/step - loss: 0.0235 - accuracy: 0.9920 - val_loss: 0.3680 - val_accuracy: 0.9123
# Epoch 11/20
# 305/305 [==============================] - 170s 558ms/step - loss: 0.0223 - accuracy: 0.9932 - val_loss: 0.4168 - val_accuracy: 0.9086
# Epoch 12/20
# 305/305 [==============================] - 170s 556ms/step - loss: 0.0236 - accuracy: 0.9917 - val_loss: 0.4368 - val_accuracy: 0.9020
# Epoch 13/20
# 305/305 [==============================] - 169s 554ms/step - loss: 0.0183 - accuracy: 0.9952 - val_loss: 0.4453 - val_accuracy: 0.9016
# Epoch 14/20
# 305/305 [==============================] - 169s 553ms/step - loss: 0.0096 - accuracy: 0.9975 - val_loss: 0.4013 - val_accuracy: 0.9172
# Epoch 15/20
# 305/305 [==============================] - 172s 563ms/step - loss: 0.0176 - accuracy: 0.9953 - val_loss: 0.4008 - val_accuracy: 0.9143
# Epoch 16/20
# 305/305 [==============================] - 170s 558ms/step - loss: 0.0083 - accuracy: 0.9977 - val_loss: 0.4304 - val_accuracy: 0.9114
# Epoch 17/20
# 305/305 [==============================] - 171s 560ms/step - loss: 0.0237 - accuracy: 0.9927 - val_loss: 0.3888 - val_accuracy: 0.9053
# Epoch 18/20
# 305/305 [==============================] - 171s 560ms/step - loss: 0.0154 - accuracy: 0.9949 - val_loss: 0.3696 - val_accuracy: 0.9176
# Epoch 19/20
# 305/305 [==============================] - 171s 559ms/step - loss: 0.0090 - accuracy: 0.9977 - val_loss: 0.3934 - val_accuracy: 0.9151
# Epoch 20/20
# 305/305 [==============================] - 169s 554ms/step - loss: 0.0151 - accuracy: 0.9951 - val_loss: 0.3655 - val_accuracy: 0.9180

# %%
# Save the resnet50V2 model into a .h5 file
model.save(base_path + 'Saved Models and Weights/' + 'my_resnet50V2_with_pretrained_celebA_model.h5')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
# Evaluates the resnet50V2 model with pretraining and prints its accuracy
loss, acc = model.evaluate(
    test_ds,
    callbacks=[WandbCallback()],
)

print("Val_accuracy", acc)
# Out:
# 77/77 [==============================] - 32s 417ms/step - loss: 0.3655 - accuracy: 0.9180
# Val_accuracy 0.9179992079734802

# %%
resnet_with_pretrained_celebA.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 396... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 301.73MB of 301.73MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▃▅▆▇▇██████████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▅▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▄▆▇▇▇▇▇▇▇▆▆██▇▇███</td></tr><tr><td>val_loss</td><td>▄▃▁▁▁▂▄▅▄▅▇██▆▆▇▆▅▆▅</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.99508</td></tr><tr><td>best_epoch</td><td>3</td></tr><tr><td>best_val_loss</td><td>0.25171</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.01513</td></tr><tr><td>val_accuracy</td><td>0.918</td></tr><tr><td>val_loss</td><td>0.36551</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 1 other file(s)
# <br/>Synced <strong style="color:#cdcd00">resnet50V2_with_pretrained_celebA</strong>: <a href="https://wandb.ai/dloe001/CZ4042_Assignment_2_Resnet_Experiments/runs/2iips205" target="_blank">https://wandb.ai/dloe001/CZ4042_Assignment_2_Resnet_Experiments/runs/2iips205</a><br/>
# Find logs at: <code>./wandb/run-20211107_045155-2iips205/logs</code><br/>
